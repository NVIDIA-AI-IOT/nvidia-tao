# %%
# %cd /content/
! wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip
# !unzip data_object_image_2.zip && rm data_object_image_2.zip
! wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip
# !unzip data_object_label_2.zip && rm data_object_label_2.zip
# ! wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_velodyne.zip
# !unzip data_object_velodyne.zip && rm data_object_velodyne.zip
# ! wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_calib.zip
# !unzip data_object_calib.zip && rm data_object_calib.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: training/label_2/001705.txt
#  extracting: training/label_2/000367.txt
#  extracting: training/label_2/006048.txt
#  extracting: training/label_2/005468.txt
#  extracting: training/label_2/007308.txt
#  extracting: training/label_2/001417.txt
#  extracting: training/label_2/006638.txt
#  extracting: training/label_2/002132.txt
#  extracting: training/label_2/002407.txt
#  extracting: training/label_2/007186.txt
#  extracting: training/label_2/004363.txt
#  extracting: training/label_2/005764.txt
#  extracting: training/label_2/003298.txt
#  extracting: training/label_2/002664.txt
#  extracting: training/label_2/002322.txt
#  extracting: training/label_2/005098.txt
#  extracting: training/label_2/007135.txt
#  extracting: training/label_2/001415.txt
#  extracting: training/label_2/000344.txt
#  extracting: training/label_2/005904.txt
#  extracting: training/label_2/007166.txt
#  extracting: training/label_2/000502.txt
# ...

# %%
# !ls /content/training/calib/* > /content/calib.txt
# !ls /content/training/calib/* | wc -l
# !ls /content/training/image_2/* | wc -l
# !ls /content/training/label_2/* | wc -l
# !ls /content/training/velodyne/* | wc -l

# !ls /content/testing/
# !ls /content/testing/calib/* > /content/calib_test.txt
# !ls /content/testing/calib/* | wc -l
# !ls /content/testing/image_2/* | wc -l
# !ls /content/testing/velodyne/* | wc -l
# Out:
# 100
# 100
# 100
# 100
# calib  image_2	velodyne
# 50
# 50
# 50

# %%
#!shuf /content/calib.txt -o /content/calib_shuf.txt
# !shuf /content/calib_test.txt -o /content/calib_test_shuf.txt

# %%
import os
selected_ids = ["002957","006083","003632","006966","005645","004645","002516","001440","006155","002821","000219","001371","001085","006535","000073","006805","005562","003332","005560","003584","004832","001270","004629","002696","004553","004485","002538","004027","004877","005621","006462","006786","002850","001152","002079","000704","001174","005321","003518","004164","002898","000797","006270","001312","000986","002837","001245","001036","005842","000348","004180","002810","006040","004662","006191","000876","003169","000935","004111","006321","007278","000724","003703","005553","001336","002487","005432","007480","001413","002600","006457","005326","001608","002220","003667","002792","002599","000571","001022","003445","001683","007110","002122","002422","000733","002117","001930","001144","001598","007011","001545","002071","000409","006397","000428","000404","002946","001034","002740","002064"]
# !mkdir /content/training/calib_subset
# !mkdir /content/training/image_2_subset
# !mkdir /content/training/label_2_subset
# !mkdir /content/training/velodyne_subset
for id in selected_ids:
  # calib = "/content/training/calib/*" + str(id) + "*"
  # os.system("cp " + calib+" /content/training/calib_subset/")
  image = "/content/training/image_2/*" + str(id) + "*"
  os.system("cp " + image+" /content/drive/MyDrive/pointpillars_data/training/image_2/")
  label = "/content/training/label_2/*" + str(id) + "*"
  os.system("cp " + label+" /content/drive/MyDrive/pointpillars_data/training/label_2/")
  # velodyne = "/content/training/velodyne/*" + str(id) + "*"
  # os.system("cp " + velodyne+" /content/training/velodyne_subset/")

# %%
import os
selected_ids = ["002988","006799","005403","005282","005955","000137","002058","000189","001395","004240","007139","001153","000310","000926","005579","002309","003085","005043","003550","001942","002004","000423","003366","002927","002604","006279","005858","006075","006203","005789","006732","005099","002744","000198","001137","005135","004304","007058","006305","003876","004469","007041","000242","001359","003408","006351","005071","001171","002345","003398"]
# !mkdir /content/testing/calib_subset
# !mkdir /content/testing/image_2_subset
# !mkdir /content/testing/label_2_subset
# !mkdir /content/testing/velodyne_subset
for id in selected_ids:
  calib = "/content/testing/calib/*" + str(id) + "*"
  os.system("cp " + calib+" /content/testing/calib_subset/")
  image = "/content/testing/image_2/*" + str(id) + "*"
  os.system("cp " + image+" /content/testing/image_2_subset/")
  label = "/content/testing/label_2/*" + str(id) + "*"
  os.system("cp " + label+" /content/testing/label_2_subset/")
  velodyne = "/content/testing/velodyne/*" + str(id) + "*"
  os.system("cp " + velodyne+" /content/testing/velodyne_subset/")

# %%
# !ls /content/training/calib_subset/* | wc -l
# !ls /content/training/image_2_subset/* | wc -l
# !ls /content/training/label_2_subset/* | wc -l
# !ls /content/training/velodyne_subset/* | wc -l

# !ls /content/testing/calib_subset/* | wc -l
# !ls /content/testing/image_2_subset/* | wc -l
# !ls /content/testing/velodyne_subset/* | wc -l
# Out:
# 100
# 100
# 100
# 100
# 50
# 50
# 50

# %%
# !ls /content/training_subset/
# !mv /content/testing_subset/label_2_subset/
# Out:
# calib_subset  image_2_subset  label_2_subset  velodyne_subset

# %%
# !rm -r training/.ipynb_checkpoints/
# !rm -r testing/.ipynb_checkpoints/

# %%
# %cd /content
# !zip -r pointcloud_subset.zip training testing
# Out:
# /content
# updating: training/ (stored 0%)
# updating: training/velodyne/ (stored 0%)
# updating: training/velodyne/001683.bin (deflated 44%)
# updating: training/velodyne/002538.bin (deflated 41%)
# updating: training/velodyne/001930.bin (deflated 40%)
# updating: training/velodyne/001608.bin (deflated 42%)
# updating: training/velodyne/003584.bin (deflated 42%)
# updating: training/velodyne/003518.bin (deflated 41%)
# updating: training/velodyne/002898.bin (deflated 41%)
# updating: training/velodyne/002696.bin (deflated 42%)
# updating: training/velodyne/002837.bin (deflated 42%)
# updating: training/velodyne/001152.bin (deflated 39%)
# updating: training/velodyne/001598.bin (deflated 41%)
# updating: training/velodyne/000733.bin (deflated 41%)
# updating: training/velodyne/004111.bin (deflated 40%)
# updating: training/velodyne/002946.bin (deflated 40%)
# updating: training/velodyne/001036.bin (deflated 42%)
# updating: training/velodyne/000704.bin (deflated 43%)
# ...

# %%
# !ls -la pointcloud_subset.zip --block-size=M
# Out:
# -rw-r--r-- 1 root root 279M Jul  6 01:22 pointcloud_subset.zip

# %%
# !cp /content/pointcloud_subset.zip /content/drive/MyDrive/pointpillars_data/
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
#!rm -rf /content/drive/MyDrive/action_rec_data/*
# !mkdir -p /content/drive/MyDrive/pointpillars_data/
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
# %cd /content/drive/MyDrive/pointpillars_data/
# !unzip pointcloud_subset.zip
# !rm pointcloud_subset.zip
# Out:
# /content/drive/MyDrive/pointpillars_data
# Archive:  pointcloud_subset.zip
#    creating: training/
#    creating: training/.ipynb_checkpoints/
#    creating: training/velodyne/
#   inflating: training/velodyne/001683.bin
#   inflating: training/velodyne/002538.bin
#   inflating: training/velodyne/001930.bin
#   inflating: training/velodyne/001608.bin
#   inflating: training/velodyne/003584.bin
#   inflating: training/velodyne/003518.bin
#   inflating: training/velodyne/002898.bin
#   inflating: training/velodyne/002696.bin
#   inflating: training/velodyne/002837.bin
#   inflating: training/velodyne/001152.bin
#   inflating: training/velodyne/001598.bin
#   inflating: training/velodyne/000733.bin
#   inflating: training/velodyne/004111.bin
#   inflating: training/velodyne/002946.bin
#   inflating: training/velodyne/001036.bin
#   inflating: training/velodyne/000704.bin
#   inflating: training/velodyne/002792.bin
#   inflating: training/velodyne/004662.bin
# ...
